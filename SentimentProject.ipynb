# %% [markdown]
# <a href="https://colab.research.google.com/github/keshavrajbux/SentimentViz/blob/main/SentimentProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: load dataset

import pandas as pd

# Load the dataset from a CSV file
df = pd.read_csv('sentimentdataset.csv')

# Print the first few rows of the dataset
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
# 1             1           1
# 2             2           2
# 3             3           3
# 4             4           4
#
#                                                 Text    Sentiment  \
# 0   Enjoying a beautiful day at the park!        ...   Positive
# 1   Traffic was terrible this morning.           ...   Negative
# 2   Just finished an amazing workout! 💪          ...   Positive
# 3   Excited about the upcoming weekend getaway!  ...   Positive
# 4   Trying out a new recipe for dinner tonight.  ...   Neutral
#
#              Timestamp            User     Platform  \
# 0  2023-01-15 12:30:00   User123          Twitter
# 1  2023-01-15 08:45:00   CommuterX        Twitter
# 2  2023-01-15 15:45:00   FitnessFan      Instagram
# 3  2023-01-15 18:20:00   AdventureX       Facebook
# 4  2023-01-15 19:55:00   ChefCook        Instagram
#
#                                      Hashtags  Retweets  Likes       Country  \
# ...

# %%
df = df.drop(columns=['Unnamed: 0.1', 'Unnamed: 0'])

# %%
df.head()
# Out:
#                                                 Text    Sentiment  \
# 0   Enjoying a beautiful day at the park!        ...   Positive
# 1   Traffic was terrible this morning.           ...   Negative
# 2   Just finished an amazing workout! 💪          ...   Positive
# 3   Excited about the upcoming weekend getaway!  ...   Positive
# 4   Trying out a new recipe for dinner tonight.  ...   Neutral
#
#              Timestamp            User     Platform  \
# 0  2023-01-15 12:30:00   User123          Twitter
# 1  2023-01-15 08:45:00   CommuterX        Twitter
# 2  2023-01-15 15:45:00   FitnessFan      Instagram
# 3  2023-01-15 18:20:00   AdventureX       Facebook
# 4  2023-01-15 19:55:00   ChefCook        Instagram
#
#                                      Hashtags  Retweets  Likes       Country  \
# 0   #Nature #Park                                  15.0   30.0     USA
# 1   #Traffic #Morning                               5.0   10.0     Canada
# ...

# %%
df.columns
# Out:
# Index(['Text', 'Sentiment', 'Timestamp', 'User', 'Platform', 'Hashtags',
#        'Retweets', 'Likes', 'Country', 'Year', 'Month', 'Day', 'Hour'],
#       dtype='object')

# %%
pip install NLTK

# %%
text_df = df["Text"]

# %%
#CleanTextFunction
def clean_text(text):
  # Remove special characters (except letters, numbers, spaces, and some punctuation)
  # text = re.sub(r"[^\w\s\?!.,:;\-+=&%()#$@]", "", text)
  text = re.sub(r'[^a-zA-Z0-9\s]+', '', text)
  # Remove hashtags and mentions
  text = re.sub(r"#\w+|\@\w+", "", text)
  # Convert to lowercase
  text = text.lower()
  return text

# %%
# Apply cleaning function to all texts
import re
cleaned_text = text_df.apply(clean_text)

# %%
# Update DataFrame with cleaned text
df["CleanText"] = cleaned_text

# %%
df.head()
# Out:
#                                                 Text    Sentiment  \
# 0   Enjoying a beautiful day at the park!        ...   Positive
# 1   Traffic was terrible this morning.           ...   Negative
# 2   Just finished an amazing workout! 💪          ...   Positive
# 3   Excited about the upcoming weekend getaway!  ...   Positive
# 4   Trying out a new recipe for dinner tonight.  ...   Neutral
#
#              Timestamp            User     Platform  \
# 0  2023-01-15 12:30:00   User123          Twitter
# 1  2023-01-15 08:45:00   CommuterX        Twitter
# 2  2023-01-15 15:45:00   FitnessFan      Instagram
# 3  2023-01-15 18:20:00   AdventureX       Facebook
# 4  2023-01-15 19:55:00   ChefCook        Instagram
#
#                                      Hashtags  Retweets  Likes       Country  \
# 0   #Nature #Park                                  15.0   30.0     USA
# 1   #Traffic #Morning                               5.0   10.0     Canada
# ...

# %%
pip install vaderSentiment

# %%
analyzer = SentimentIntensityAnalyzer()

# %%
df.columns
# Out:
# Index(['Text', 'Sentiment', 'Timestamp', 'User', 'Platform', 'Hashtags',
#        'Retweets', 'Likes', 'Country', 'Year', 'Month', 'Day', 'Hour',
#        'CleanText'],
#       dtype='object')

# %%
pip install --upgrade vaderSentiment

# %%
df.columns
# Out:
# Index(['Text', 'Sentiment', 'Timestamp', 'User', 'Platform', 'Hashtags',
#        'Retweets', 'Likes', 'Country', 'Year', 'Month', 'Day', 'Hour',
#        'CleanText'],
#       dtype='object')

# %%
# Define columns to store sentiment results
sentiment_columns = ['sentiment', 'compound_score', 'positive_score']

import pandas as pd
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# Initialize sentiment analyzer
analyzer = SentimentIntensityAnalyzer()

# Loop through each text entry and analyze sentiment
for index, row in df.iterrows():
    text = row['CleanText']
    sentiment = analyzer.polarity_scores(text)

    # Extract relevant scores and store them in corresponding columns
    df.loc[index, sentiment_columns] = sentiment['compound'], sentiment['pos'], sentiment['pos']

print(df)
# Out:
#                                                   Text    Sentiment  \
# 0     Enjoying a beautiful day at the park!        ...   Positive
# 1     Traffic was terrible this morning.           ...   Negative
# 2     Just finished an amazing workout! 💪          ...   Positive
# 3     Excited about the upcoming weekend getaway!  ...   Positive
# 4     Trying out a new recipe for dinner tonight.  ...   Neutral
# ..                                                 ...          ...
# 727  Collaborating on a science project that receiv...       Happy
# 728  Attending a surprise birthday party organized ...       Happy
# 729  Successfully fundraising for a school charity ...       Happy
# 730  Participating in a multicultural festival, cel...       Happy
# 731  Organizing a virtual talent show during challe...       Happy
#
#                Timestamp                                   User     Platform  \
# 0    2023-01-15 12:30:00                          User123          Twitter
# ...

# %%
df['Sentiment'][4]
# Out:
# ' Neutral   '

# %%
df['Sentiment'] == 'Positive'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 727    False
# 728    False
# 729    False
# 730    False
# 731    False
# Name: Sentiment, Length: 732, dtype: bool

# %%
# Calculate sentiment distribution with error handling
positive_count = len(df[df['Sentiment'] == ' Positive  '])
negative_count = len(df[df['Sentiment'] == ' Negative  '])
neutral_count = len(df[df['Sentiment'] == ' Neutral   '])

# %%
positive_count
# Out:
# 44

# %%
negative_count
# Out:
# 4

# %%
neutral_count
# Out:
# 4

# %%
df.columns
# Out:
# Index(['Text', 'Sentiment', 'Timestamp', 'User', 'Platform', 'Hashtags',
#        'Retweets', 'Likes', 'Country', 'Year', 'Month', 'Day', 'Hour',
#        'CleanText', 'sentiment', 'compound_score', 'positive_score'],
#       dtype='object')

# %%
# Small value to avoid division by zero (optional)
epsilon = 0.001  # Modify if needed

# %%
# Check for empty DataFrame
if df.empty:
    print("Error: DataFrame is empty. No sentiment analysis possible.")
else:
    total_count = positive_count + negative_count + neutral_count + epsilon

# %%
# Calculate percentages with safe division
positive_pct = (positive_count / total_count) * 100
negative_pct = (negative_count / total_count) * 100
neutral_pct = (neutral_count / total_count) * 100

print(f"Positive: {positive_pct:.2f}%, Negative: {negative_pct:.2f}%, Neutral: {neutral_pct:.2f}%")
# Out:
# Positive: 84.61%, Negative: 7.69%, Neutral: 7.69%

# %%
# Visualizations:
import matplotlib.pyplot as plt

# Bar Chart
sentiment_counts = [positive_count, negative_count, neutral_count]
sentiment_labels = ['Positive', 'Negative', 'Neutral']

plt.bar(sentiment_labels, sentiment_counts)
plt.xlabel("Sentiment")
plt.ylabel("Number of Texts")
plt.title("Sentiment Distribution")
plt.show()

# %%
# Pie Chart
plt.pie(sentiment_counts, labels=sentiment_labels, autopct="%1.1f%%")
plt.title("Sentiment Distribution")
plt.show()

# %%
# Histogram of Compound Sentiment Scores
plt.hist(df['compound_score'], bins=20)
plt.xlabel("Compound Sentiment Score")
plt.ylabel("Frequency")
plt.title("Distribution of Sentiment Scores")
plt.show()

# %%
# Box Plots of Sentiment Scores by Sentiment Category:
plt.boxplot([df[df['Sentiment'] == ' Positive  ']['compound_score'],
             df[df['Sentiment'] == ' Negative  ']['compound_score'],
             df[df['Sentiment'] == ' Neutral   ']['compound_score']],
            labels=['Positive', 'Negative', 'Neutral'])
plt.title("Compound Sentiment Scores by Sentiment Category")
plt.show()

# %%
#  Scatter Plot of Compound Score vs. Positive Score
plt.scatter(df['compound_score'], df['positive_score'])
plt.xlabel("Compound Sentiment Score")
plt.ylabel("Positive Sentiment Score")
plt.title("Relationship Between Compound and Positive Sentiment")
plt.show()

# %%
# Word Cloud of Most Frequent Words in Each Sentiment Category
from wordcloud import WordCloud

for sentiment in [' Positive  ', ' Negative  ', ' Neutral   ']:
    words = ' '.join(df[df['Sentiment'] == sentiment]['CleanText'])
    wordcloud = WordCloud(width=800, height=400).generate(words)
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.title(f"Word Cloud for {sentiment} Sentiment")
    plt.show()
